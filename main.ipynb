# %%
from IPython.display import display, clear_output
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time

from loaders.options_chain import load_options_chain_dataframe
from nodes import NodesDataframe
import plots as plot

# %%
"""
Reload all modules AND autoload newly added objects
  every time before executing the Python code typed.
"""

# %load_ext autoreload
# %autoreload 3

# %% [markdown]
# ## 1. Settings

# %%
start_date = '2024-01-21 23:50:00'
end_date = '2024-01-22 01:00:00'

tokens = {
    'source': ['eth'],
    'target': ['btc', 'ant', 'solo', 'axl']
}

symbols = {
    'source': ['ethusd'],
    'target': ['btcusd', 'antusd', 'solousd', 'axlusd']
}

instrument_ids = {
    'source': ['binance_eth_usdt_spot'],
    'target': ['binance_btc_usdt_spot', 'aggregated_ant_usd_spot', 'aggregated_solo_usd_spot', 'aggregated_axl_usd_spot']
}

volatility_curve_extrapolation_types = ['flat', 'square_root_law', 'power_law']

# %% [markdown]
# ## 2. Data Handling

# %% [markdown]
# **Options Chain**

# %%
df_options = load_options_chain_dataframe('2023-07-20 21:00:00', '2023-07-21 00:01:00', tokens, symbols, instrument_ids, period='minute')
# Out:
# ['2023-07-20 21:00:00', '2023-07-20 21:01:00', '2023-07-20 21:02:00', '2023-07-20 21:03:00', '2023-07-20 21:04:00', '2023-07-20 21:05:00', '2023-07-20 21:06:00', '2023-07-20 21:07:00', '2023-07-20 21:08:00', '2023-07-20 21:09:00', '2023-07-20 21:10:00', '2023-07-20 21:11:00', '2023-07-20 21:12:00', '2023-07-20 21:13:00', '2023-07-20 21:14:00', '2023-07-20 21:15:00', '2023-07-20 21:16:00', '2023-07-20 21:17:00', '2023-07-20 21:18:00', '2023-07-20 21:19:00', '2023-07-20 21:20:00', '2023-07-20 21:21:00', '2023-07-20 21:22:00', '2023-07-20 21:23:00', '2023-07-20 21:24:00', '2023-07-20 21:25:00', '2023-07-20 21:26:00', '2023-07-20 21:27:00', '2023-07-20 21:28:00', '2023-07-20 21:29:00', '2023-07-20 21:30:00', '2023-07-20 21:31:00', '2023-07-20 21:32:00', '2023-07-20 21:33:00', '2023-07-20 21:34:00', '2023-07-20 21:35:00', '2023-07-20 21:36:00', '2023-07-20 21:37:00', '2023-07-20 21:38:00', '2023-07-20 21:39:00', '2023-07-20 21:40:00', '2023-07-20 21:41:00', '2023-07-20 21:42:00', '2023-07-20 21:43:00', '2023-07-20 21:44:00', '2023-07-20 21:45:00', '2023-07-20 21:46:00', '2023-07-20 21:47:00', '2023-07-20 21:48:00', '2023-07-20 21:49:00', '2023-07-20 21:50:00', '2023-07-20 21:51:00', '2023-07-20 21:52:00', '2023-07-20 21:53:00', '2023-07-20 21:54:00', '2023-07-20 21:55:00', '2023-07-20 21:56:00', '2023-07-20 21:57:00', '2023-07-20 21:58:00', '2023-07-20 21:59:00']
# Missing ts values: 0
# Missing ts values: 0

# %%
df_options[:50]
# Out:
#           current_date token     expiration_date       K        F  \
# 0  2023-07-20 21:00:00   eth 2023-07-28 08:00:00  1750.0  1890.12
# 1  2023-07-20 21:00:00   eth 2023-07-28 08:00:00  1800.0  1890.12
# 2  2023-07-20 21:00:00   eth 2023-07-28 08:00:00  1850.0  1890.12
# 3  2023-07-20 21:00:00   eth 2023-07-28 08:00:00  1900.0  1890.12
# 4  2023-07-20 21:00:00   eth 2023-07-28 08:00:00  1950.0  1890.12
# 5  2023-07-20 21:00:00   eth 2023-07-28 08:00:00  2000.0  1890.12
# 6  2023-07-20 21:00:00   eth 2023-07-28 08:00:00  2050.0  1890.12
# 7  2023-07-20 21:00:00   eth 2023-07-28 08:00:00  2100.0  1890.12
# 8  2023-07-20 21:00:00   eth 2023-08-25 08:00:00  1400.0  1895.20
# 9  2023-07-20 21:00:00   eth 2023-08-25 08:00:00  1500.0  1895.20
# 10 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  1600.0  1895.20
# 11 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  1700.0  1895.20
# 12 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  1800.0  1895.20
# 13 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  1900.0  1895.20
# 14 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  2000.0  1895.20
# 15 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  2100.0  1895.20
# 16 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  2200.0  1895.20
# 17 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  2300.0  1895.20
# 18 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  2400.0  1895.20
# 19 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  2500.0  1895.20
# 20 2023-07-20 21:00:00   eth 2023-08-25 08:00:00  2600.0  1895.20
# 21 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  1100.0  1902.89
# 22 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  1200.0  1902.88
# 23 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  1300.0  1902.88
# 24 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  1400.0  1902.88
# 25 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  1500.0  1902.88
# 26 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  1600.0  1902.88
# 27 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  1700.0  1902.88
# 28 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  1800.0  1902.88
# 29 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  1900.0  1902.88
# 30 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  2000.0  1902.89
# 31 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  2100.0  1902.88
# 32 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  2200.0  1902.88
# 33 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  2300.0  1902.88
# 34 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  2400.0  1902.88
# 35 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  2500.0  1902.88
# 36 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  2600.0  1902.88
# 37 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  3000.0  1902.88
# 38 2023-07-20 21:00:00   eth 2023-09-29 08:00:00  3500.0  1902.89
# 39 2023-07-20 21:00:00   eth 2023-12-29 08:00:00   800.0  1922.64
# 40 2023-07-20 21:00:00   eth 2023-12-29 08:00:00  1000.0  1922.64
# 41 2023-07-20 21:00:00   eth 2023-12-29 08:00:00  1100.0  1922.69
# 42 2023-07-20 21:00:00   eth 2023-12-29 08:00:00  1200.0  1922.64
# 43 2023-07-20 21:00:00   eth 2023-12-29 08:00:00  1300.0  1922.65
# 44 2023-07-20 21:00:00   eth 2023-12-29 08:00:00  1400.0  1922.64
# 45 2023-07-20 21:00:00   eth 2023-12-29 08:00:00  1500.0  1922.64
# 46 2023-07-20 21:00:00   eth 2023-12-29 08:00:00  1600.0  1922.64
# 47 2023-07-20 21:00:00   eth 2023-12-29 08:00:00  1700.0  1922.64
# 48 2023-07-20 21:00:00   eth 2023-12-29 08:00:00  1800.0  1922.64
# 49 2023-07-20 21:00:00   eth 2023-12-29 08:00:00  1900.0  1922.64
#
#     option_price            S         T         r      rv        iv     delta
# 0       5.481348  1888.071362  0.020420  0.053108  0.4363  0.427393  0.901772
# 1      10.584672  1888.071362  0.020420  0.053108  0.4363  0.387547  0.818549
# 2      21.547368  1888.071362  0.020420  0.053108  0.4363  0.359662  0.671169
# 3      33.455124  1888.071362  0.020420  0.053108  0.4363  0.353895  0.468990
# 4      16.633056  1888.071362  0.020420  0.053108  0.4363  0.361811  0.281836
# 5       8.694552  1888.071362  0.020420  0.053108  0.4363  0.388723  0.161211
# 6       5.670360  1888.071362  0.020420  0.053108  0.4363  0.438773  0.103168
# 7       3.969252  1888.071362  0.020420  0.053108  0.4363  0.487873  0.070037
# 8       4.927520  1888.071362  0.097080  0.038819  0.4363  0.564373  0.964867
# 9       7.770320  1888.071362  0.097080  0.038819  0.4363  0.502035  0.942171
# 10     13.076880  1888.071362  0.097080  0.038819  0.4363  0.446756  0.900778
# 11     24.827120  1888.071362  0.097080  0.038819  0.4363  0.408548  0.820572
# 12     47.380000  1888.071362  0.097080  0.038819  0.4363  0.379120  0.689828
# 13     84.904960  1888.071362  0.097080  0.038819  0.4363  0.371613  0.514377
# 14     47.759040  1888.071362  0.097080  0.038819  0.4363  0.375744  0.344136
# 15     26.722320  1888.071362  0.097080  0.038819  0.4363  0.389578  0.216323
# 16     15.730160  1888.071362  0.097080  0.038819  0.4363  0.411335  0.135765
# 17     10.044560  1888.071362  0.097080  0.038819  0.4363  0.438739  0.088866
# 18      7.012240  1888.071362  0.097080  0.038819  0.4363  0.470084  0.061898
# 19      5.117040  1888.071362  0.097080  0.038819  0.4363  0.500550  0.044763
# 20      3.979920  1888.071362  0.097080  0.038819  0.4363  0.532378  0.034135
# 21      4.757225  1888.071362  0.192904  0.040527  0.4363  0.661975  0.978842
# 22      6.660080  1888.071362  0.192904  0.040500  0.4363  0.605323  0.969055
# 23      9.894976  1888.071362  0.192904  0.040500  0.4363  0.558789  0.953047
# 24     14.461888  1888.071362  0.192904  0.040500  0.4363  0.512903  0.929890
# 25     22.263696  1888.071362  0.192904  0.040500  0.4363  0.476301  0.892850
# 26     35.203280  1888.071362  0.192904  0.040500  0.4363  0.447470  0.836552
# 27     56.134960  1888.071362  0.192904  0.040500  0.4363  0.426697  0.756559
# 28     87.913056  1888.071362  0.192904  0.040500  0.4363  0.413105  0.654338
# 29    133.391888  1888.071362  0.192904  0.040500  0.4363  0.408368  0.539083
# 30     96.286234  1888.071362  0.192904  0.040527  0.4363  0.410904  0.426396
# 31     67.932816  1888.071362  0.192904  0.040500  0.4363  0.418383  0.328330
# 32     48.713728  1888.071362  0.192904  0.040500  0.4363  0.430435  0.250495
# 33     35.393568  1888.071362  0.192904  0.040500  0.4363  0.443711  0.190745
# 34     26.640320  1888.071362  0.192904  0.040500  0.4363  0.460322  0.147569
# 35     20.931680  1888.071362  0.192904  0.040500  0.4363  0.479997  0.117186
# 36     16.174480  1888.071362  0.192904  0.040500  0.4363  0.494918  0.092205
# 37      7.801808  1888.071362  0.192904  0.040500  0.4363  0.566968  0.044223
# 38      4.186358  1888.071362  0.192904  0.040527  0.4363  0.648352  0.022879
# 39      6.152448  1888.071362  0.442049  0.041044  0.4363  0.695391  0.983319
# 40     12.497160  1888.071362  0.442049  0.041044  0.4363  0.612094  0.964834
# 41     18.265555  1888.071362  0.442049  0.041103  0.4363  0.582726  0.948979
# 42     25.955640  1888.071362  0.442049  0.041044  0.4363  0.554860  0.928159
# 43     36.530350  1888.071362  0.442049  0.041056  0.4363  0.530640  0.900713
# 44     50.565432  1888.071362  0.442049  0.041044  0.4363  0.508670  0.865873
# 45     70.176360  1888.071362  0.442049  0.041044  0.4363  0.492777  0.821600
# 46     96.516528  1888.071362  0.442049  0.041044  0.4363  0.481880  0.768388
# 47    130.547256  1888.071362  0.442049  0.041044  0.4363  0.475271  0.707972
# 48    172.845336  1888.071362  0.442049  0.041044  0.4363  0.472416  0.643152
# 49    223.603032  1888.071362  0.442049  0.041044  0.4363  0.473077  0.577275

# %% [markdown]
# **Nodes**

# %%
dataframes_list = []

for volatility_curve_extrapolation_type in volatility_curve_extrapolation_types:

    df_nodes = NodesDataframe(df_options, volatility_curve_extrapolation_type).df_nodes

    dataframes_list.append(df_nodes)

df_nodes = pd.concat(dataframes_list).reset_index(drop=True)
# Out:
# token: eth | current date: 2023-07-20 21:00:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:00:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:00:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:00:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:00:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:00:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:01:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:01:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:01:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:01:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:01:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:01:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:02:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:02:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:02:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:02:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:02:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:02:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:03:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:03:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:03:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:03:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:03:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:03:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:04:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:04:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:04:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:04:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:04:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:04:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:05:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:05:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:05:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:05:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:05:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:05:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:06:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:06:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:06:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:06:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:06:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:06:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:07:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:07:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:07:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:07:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:07:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:07:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:08:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:08:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:08:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:08:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:08:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:08:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:09:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:09:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:09:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:09:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:09:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:09:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:10:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:10:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:10:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:10:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:10:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:10:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:11:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:11:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:11:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:11:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:11:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:11:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:12:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:12:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:12:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:12:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:12:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:12:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:13:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:13:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:13:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:13:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:13:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:13:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:14:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:14:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:14:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:14:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:14:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:14:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:15:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:15:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:15:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:15:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:15:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:15:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:16:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:16:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:16:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:16:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:16:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:16:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:17:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:17:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:17:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:17:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:17:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:17:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:18:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:18:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:18:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:18:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:18:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:18:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:19:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:19:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:19:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:19:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:19:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:19:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:20:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:20:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:20:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:20:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:20:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:20:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:21:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:21:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:21:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:21:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:21:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:21:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:22:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:22:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:22:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:22:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:22:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:22:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:23:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:23:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:23:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:23:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:23:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:23:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:24:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:24:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:24:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:24:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:24:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:24:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:25:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:25:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:25:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:25:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:25:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:25:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:26:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:26:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:26:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:26:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:26:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:26:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:27:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:27:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:27:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:27:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:27:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:27:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:28:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:28:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:28:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:28:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:28:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:28:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:29:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:29:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:29:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:29:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:29:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:29:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:30:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:30:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:30:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:30:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:30:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:30:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:31:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:31:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:31:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:31:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:31:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:31:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:32:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:32:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:32:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:32:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:32:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:32:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:33:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:33:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:33:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:33:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:33:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:33:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:34:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:34:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:34:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:34:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:34:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:34:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:35:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:35:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:35:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:35:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:35:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:35:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:36:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:36:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:36:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:36:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:36:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:36:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:37:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:37:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:37:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:37:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:37:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:37:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:38:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:38:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:38:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:38:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:38:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:38:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:39:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:39:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:39:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:39:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:39:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:39:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:40:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:40:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:40:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:40:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:40:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:40:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:41:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:41:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:41:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:41:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:41:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:41:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:42:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:42:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:42:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:42:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:42:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:42:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:43:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:43:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:43:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:43:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:43:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:43:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:44:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:44:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:44:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:44:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:44:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:44:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:45:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:45:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:45:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:45:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:45:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:45:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:46:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:46:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:46:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:46:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:46:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:46:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:47:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:47:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:47:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:47:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:47:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:47:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:48:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:48:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:48:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:48:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:48:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:48:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:49:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:49:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:49:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:49:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:49:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:49:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:50:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:50:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:50:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:50:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:50:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:50:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:51:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:51:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:51:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:51:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:51:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:51:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:52:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:52:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:52:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:52:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:52:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:52:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:53:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:53:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:53:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:53:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:53:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:53:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:54:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:54:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:54:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:54:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:54:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:54:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:55:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:55:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:55:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:55:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:55:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:55:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:56:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:56:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:56:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:56:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:56:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:56:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:57:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:57:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:57:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:57:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:57:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:57:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:58:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:58:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:58:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:58:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:58:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:58:00 | expiration date: 2024-06-28 08:00:00
# token: eth | current date: 2023-07-20 21:59:00 | expiration date: 2023-07-28 08:00:00
# token: eth | current date: 2023-07-20 21:59:00 | expiration date: 2023-08-25 08:00:00
# token: eth | current date: 2023-07-20 21:59:00 | expiration date: 2023-09-29 08:00:00
# token: eth | current date: 2023-07-20 21:59:00 | expiration date: 2023-12-29 08:00:00
# token: eth | current date: 2023-07-20 21:59:00 | expiration date: 2024-03-29 08:00:00
# token: eth | current date: 2023-07-20 21:59:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:00:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:00:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:00:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:00:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:00:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:00:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:01:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:01:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:01:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:01:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:01:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:01:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:02:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:02:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:02:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:02:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:02:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:02:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:03:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:03:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:03:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:03:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:03:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:03:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:04:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:04:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:04:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:04:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:04:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:04:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:05:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:05:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:05:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:05:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:05:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:05:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:06:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:06:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:06:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:06:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:06:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:06:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:07:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:07:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:07:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:07:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:07:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:07:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:08:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:08:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:08:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:08:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:08:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:08:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:09:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:09:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:09:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:09:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:09:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:09:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:10:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:10:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:10:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:10:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:10:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:10:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:11:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:11:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:11:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:11:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:11:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:11:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:12:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:12:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:12:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:12:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:12:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:12:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:13:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:13:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:13:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:13:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:13:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:13:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:14:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:14:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:14:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:14:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:14:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:14:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:15:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:15:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:15:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:15:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:15:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:15:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:16:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:16:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:16:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:16:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:16:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:16:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:17:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:17:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:17:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:17:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:17:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:17:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:18:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:18:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:18:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:18:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:18:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:18:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:19:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:19:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:19:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:19:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:19:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:19:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:20:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:20:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:20:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:20:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:20:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:20:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:21:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:21:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:21:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:21:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:21:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:21:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:22:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:22:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:22:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:22:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:22:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:22:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:23:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:23:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:23:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:23:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:23:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:23:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:24:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:24:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:24:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:24:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:24:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:24:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:25:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:25:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:25:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:25:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:25:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:25:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:26:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:26:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:26:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:26:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:26:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:26:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:27:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:27:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:27:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:27:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:27:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:27:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:28:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:28:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:28:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:28:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:28:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:28:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:29:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:29:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:29:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:29:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:29:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:29:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:30:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:30:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:30:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:30:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:30:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:30:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:31:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:31:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:31:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:31:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:31:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:31:00 | expiration date: 2024-06-28 08:00:00
# token: btc | current date: 2023-07-20 21:32:00 | expiration date: 2023-07-28 08:00:00
# token: btc | current date: 2023-07-20 21:32:00 | expiration date: 2023-08-25 08:00:00
# token: btc | current date: 2023-07-20 21:32:00 | expiration date: 2023-09-29 08:00:00
# token: btc | current date: 2023-07-20 21:32:00 | expiration date: 2023-12-29 08:00:00
# token: btc | current date: 2023-07-20 21:32:00 | expiration date: 2024-03-29 08:00:00
# token: btc | current date: 2023-07-20 21:32:00 | expiration date: 2024-06-28 08:00:00
# ...
# token: axl | current date: 2023-07-20 21:29:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:29:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:29:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:29:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:29:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:29:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:30:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:30:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:30:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:30:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:30:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:30:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:31:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:31:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:31:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:31:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:31:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:31:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:32:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:32:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:32:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:32:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:32:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:32:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:33:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:33:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:33:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:33:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:33:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:33:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:34:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:34:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:34:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:34:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:34:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:34:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:35:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:35:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:35:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:35:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:35:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:35:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:36:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:36:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:36:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:36:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:36:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:36:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:37:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:37:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:37:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:37:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:37:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:37:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:38:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:38:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:38:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:38:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:38:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:38:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:39:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:39:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:39:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:39:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:39:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:39:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:40:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:40:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:40:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:40:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:40:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:40:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:41:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:41:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:41:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:41:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:41:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:41:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:42:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:42:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:42:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:42:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:42:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:42:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:43:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:43:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:43:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:43:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:43:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:43:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:44:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:44:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:44:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:44:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:44:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:44:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:45:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:45:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:45:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:45:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:45:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:45:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:46:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:46:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:46:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:46:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:46:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:46:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:47:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:47:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:47:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:47:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:47:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:47:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:48:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:48:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:48:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:48:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:48:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:48:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:49:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:49:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:49:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:49:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:49:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:49:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:50:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:50:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:50:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:50:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:50:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:50:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:51:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:51:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:51:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:51:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:51:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:51:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:52:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:52:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:52:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:52:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:52:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:52:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:53:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:53:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:53:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:53:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:53:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:53:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:54:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:54:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:54:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:54:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:54:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:54:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:55:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:55:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:55:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:55:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:55:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:55:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:56:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:56:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:56:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:56:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:56:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:56:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:57:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:57:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:57:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:57:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:57:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:57:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:58:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:58:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:58:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:58:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:58:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:58:00 | expiration date: 2024-06-28 08:00:00
# token: axl | current date: 2023-07-20 21:59:00 | expiration date: 2023-07-28 08:00:00
# token: axl | current date: 2023-07-20 21:59:00 | expiration date: 2023-08-25 08:00:00
# token: axl | current date: 2023-07-20 21:59:00 | expiration date: 2023-09-29 08:00:00
# token: axl | current date: 2023-07-20 21:59:00 | expiration date: 2023-12-29 08:00:00
# token: axl | current date: 2023-07-20 21:59:00 | expiration date: 2024-03-29 08:00:00
# token: axl | current date: 2023-07-20 21:59:00 | expiration date: 2024-06-28 08:00:00

# %%
df_nodes
# Out:
#      token        current_date     expiration_date         T         r  \
# 0      eth 2023-07-20 21:00:00 2023-07-28 08:00:00  0.020420  0.053108
# 1      eth 2023-07-20 21:00:00 2023-08-25 08:00:00  0.097080  0.038819
# 2      eth 2023-07-20 21:00:00 2023-09-29 08:00:00  0.192904  0.040527
# 3      eth 2023-07-20 21:00:00 2023-12-29 08:00:00  0.442049  0.041044
# 4      eth 2023-07-20 21:00:00 2024-03-29 08:00:00  0.691193  0.042733
# ...    ...                 ...                 ...       ...       ...
# 5395   axl 2023-07-20 21:59:00 2023-08-25 08:00:00  0.096967  0.041081
# 5396   axl 2023-07-20 21:59:00 2023-09-29 08:00:00  0.192792  0.040774
# 5397   axl 2023-07-20 21:59:00 2023-12-29 08:00:00  0.441937  0.040838
# 5398   axl 2023-07-20 21:59:00 2024-03-29 08:00:00  0.691081  0.042768
# 5399   axl 2023-07-20 21:59:00 2024-06-28 08:00:00  0.940225  0.039168
#
#                 S            F  \
# 0     1888.071362  1890.120000
# 1     1888.071362  1895.200000
# 2     1888.071362  1902.890000
# 3     1888.071362  1922.640000
# 4     1888.071362  1944.670000
# ...           ...          ...
# 5395     0.364700     0.366156
# 5396     0.364700     0.367578
# 5397     0.364700     0.371342
# 5398     0.364700     0.375640
# 5399     0.364700     0.378381
#
#                                          observed_delta  \
# 0     [0.901771778183381, 0.8185490696750937, 0.6711...
# 1     [0.9648668604162155, 0.9421709732242379, 0.900...
# 2     [0.978842205641508, 0.9690550144804703, 0.9530...
# 3     [0.9833186774487411, 0.9648344634934667, 0.948...
# 4     [0.9879478609716452, 0.9718224859535314, 0.943...
# ...                                                 ...
# 5395  [0.9653126561744076, 0.9439581380943486, 0.903...
# 5396  [0.9790022355955376, 0.9693216872592347, 0.954...
# 5397  [0.9834047582240039, 0.9654075850340242, 0.949...
# 5398  [0.9879987252668161, 0.9722266383272503, 0.943...
# 5399  [0.9816530545330846, 0.9621854263450185, 0.930...
#
#                                              observed_K  \
# 0     [1750.0, 1800.0, 1850.0, 1900.0, 1950.0, 2000....
# 1     [1400.0, 1500.0, 1600.0, 1700.0, 1800.0, 1900....
# 2     [1100.0, 1200.0, 1300.0, 1400.0, 1500.0, 1600....
# 3     [800.0, 1000.0, 1100.0, 1200.0, 1300.0, 1400.0...
# 4     [600.0, 800.0, 1000.0, 1200.0, 1400.0, 1500.0,...
# ...                                                 ...
# 5395  [0.2536502926257301, 0.27540776886625934, 0.29...
# 5396  [0.19080641946478824, 0.2115338895193035, 0.23...
# 5397  [0.13183018586122724, 0.17145163174705993, 0.1...
# 5398  [0.09471819863750357, 0.13282015769554706, 0.1...
# 5399  [0.0957086035822866, 0.13392776288737362, 0.17...
#
#                                             observed_iv  \
# 0     [0.42739299239590756, 0.38754669273272147, 0.3...
# 1     [0.5643725818954409, 0.5020354919321836, 0.446...
# 2     [0.661974909286946, 0.6053228023461997, 0.5587...
# 3     [0.6953910775296388, 0.6120944795571267, 0.582...
# 4     [0.7236105052568018, 0.6526587719283998, 0.597...
# ...                                                 ...
# 5395  [0.6899993164199841, 0.6123725340382302, 0.548...
# 5396  [0.8041316151925783, 0.7362291562798556, 0.674...
# 5397  [0.8421274105840562, 0.7398482382277747, 0.705...
# 5398  [0.875374484899215, 0.7880068054008751, 0.7260...
# 5399  [0.8437863045227768, 0.7608695826444789, 0.704...
#
#                                              observed_C extrapolation_type  \
# 0     [145.44947679043412, 100.6069937966679, 61.623...               flat
# 1     [498.26486621301933, 401.48380759125735, 307.1...               flat
# 2     [801.3947690422649, 704.0760261327061, 608.089...               flat
# 3     [1108.6076311033316, 918.5482994626396, 826.11...               flat
# 4     [1311.3680694219754, 1124.9676486844742, 944.7...               flat
# ...                                                 ...                ...
# 5395  [0.11322119859139163, 0.09217503159125284, 0.0...          power_law
# 5396  [0.17651976309755527, 0.15640572488268767, 0.1...          power_law
# 5397  [0.236712637150909, 0.19927875253893906, 0.180...          power_law
# 5398  [0.2741647732696436, 0.23902053142971375, 0.20...          power_law
# 5399  [0.27515799569341914, 0.2411137981826348, 0.20...          power_law
#
#                                             nodes_delta  \
# 0                           [0.85, 0.7, 0.5, 0.3, 0.15]
# 1               [0.93, 0.85, 0.7, 0.5, 0.3, 0.15, 0.07]
# 2     [0.97, 0.93, 0.85, 0.7, 0.5, 0.3, 0.15, 0.07, ...
# 3     [0.97, 0.93, 0.85, 0.7, 0.5, 0.3, 0.15, 0.07, ...
# 4     [0.97, 0.93, 0.85, 0.7, 0.5, 0.3, 0.15, 0.07, ...
# ...                                                 ...
# 5395            [0.93, 0.85, 0.7, 0.5, 0.3, 0.15, 0.07]
# 5396  [0.97, 0.93, 0.85, 0.7, 0.5, 0.3, 0.15, 0.07, ...
# 5397  [0.97, 0.93, 0.85, 0.7, 0.5, 0.3, 0.15, 0.07, ...
# 5398  [0.97, 0.93, 0.85, 0.7, 0.5, 0.3, 0.15, 0.07, ...
# 5399      [0.97, 0.93, 0.85, 0.7, 0.5, 0.3, 0.15, 0.07]
#
#                                                 nodes_K  \
# 0              [1775.0, 1837.5, 1887.5, 1937.5, 2025.0]
# 1     [1550.0, 1650.0, 1775.0, 1912.5, 2050.0, 2150....
# 2     [1150.0, 1350.0, 1550.0, 1750.0, 1950.0, 2150....
# 3     [900.0, 1150.0, 1450.0, 1750.0, 2050.0, 2450.0...
# 4     [900.0, 1100.0, 1300.0, 1750.0, 2150.0, 2700.0...
# ...                                                 ...
# 5395  [0.28645256698919475, 0.3086936370994291, 0.34...
# 5396  [0.20117015449204587, 0.26495407346766464, 0.2...
# 5397  [0.1516409088041436, 0.20238501066915301, 0.26...
# 5398  [0.15282844025950507, 0.19362403798378264, 0.2...
# 5399  [0.11481818323483012, 0.19516408697341056, 0.2...
#
#                                                nodes_iv  \
# 0     [0.4069751938468437, 0.36463651315459905, 0.35...
# 1     [0.472453982924102, 0.426192634652396, 0.38478...
# 2     [0.631440671706952, 0.5353021231426144, 0.4609...
# 3     [0.6474404305014225, 0.5684808704753674, 0.499...
# 4     [0.6232317220345479, 0.575917421033504, 0.5414...
# ...                                                 ...
# 5395  [0.5790811633720679, 0.5189217370238112, 0.457...
# 5396  [0.7692938038572071, 0.5988335307714537, 0.559...
# 5397  [0.7826771537266466, 0.6892355766270618, 0.604...
# 5398  [0.7545894692758641, 0.6991477223326684, 0.656...
# 5399  [0.7996527520090928, 0.690452790282235, 0.6615...
#
#                                                 nodes_C  \
# 0     [122.5799794519744, 70.52285333325312, 39.3694...
# 1     [353.8134104698602, 262.1861740257343, 159.978...
# 2     [752.5685362983488, 560.5203516024146, 378.078...
# 3     [1012.8019441532351, 780.5729282829824, 523.71...
# 4     [1033.8774078129613, 858.2777268126928, 695.30...
# ...                                                 ...
# 5395  [0.08170066683222055, 0.06126930685052279, 0.0...
# 5396  [0.16644289748878915, 0.10595696093668985, 0.0...
# 5397  [0.2178234520696979, 0.1711668738118869, 0.117...
# 5398  [0.22111814245315936, 0.18608792963349646, 0.1...
# 5399  [0.2579946406030824, 0.19099571406389468, 0.16...
#
#                                           func_callable
# 0     <bound method StrikeVolatilityModelling.get_iv...
# 1     <bound method StrikeVolatilityModelling.get_iv...
# 2     <bound method StrikeVolatilityModelling.get_iv...
# 3     <bound method StrikeVolatilityModelling.get_iv...
# 4     <bound method StrikeVolatilityModelling.get_iv...
# ...                                                 ...
# 5395  <bound method StrikeVolatilityModelling.get_iv...
# 5396  <bound method StrikeVolatilityModelling.get_iv...
# 5397  <bound method StrikeVolatilityModelling.get_iv...
# 5398  <bound method StrikeVolatilityModelling.get_iv...
# 5399  <bound method StrikeVolatilityModelling.get_iv...
#
# [5400 rows x 17 columns]

# %% [markdown]
# # 3. Plots

# %% [markdown]
# Weird datapoints:
# - current_date == '2023-11-18 00:00:00' + expiration_date == '2024-06-28 08:00:00' or '2024-09-27 08:00:00

# %%
display(list(sorted(df_nodes['token'].unique())))

display(list(sorted(df_nodes['expiration_date'].unique())))

# %% [markdown]
# ### 3.1. Volatility Smile - Sample Strike Values

# %%
tokens = df_options['token'].unique()
tokens = ['eth']

extrapolation_type = 'flat'

for token in tokens:
    current_dates = df_options['current_date'].unique()
    current_dates = ['2024-01-21 23:59:00']

    for i, current_date in enumerate(current_dates):
        clear_output(wait=True)

        filtered_df_nodes = df_nodes.loc[
            (df_nodes['current_date'] == current_date) &
            (df_nodes['token'] == token) &
            (df_nodes['extrapolation_type'] == extrapolation_type)
        ]

        # Call your plotting function
        plot.volatility_smile_fixed_T_sample_strike_values(
            filtered_df_nodes
        )

        display(plt.gcf())
        time.sleep(3)
        plt.close()

# %% [markdown]
# ### 3.2 Implied Volatility change to Spot Price (for a fixed Strike Price)

# %% [markdown]
# **Procedure**:
#
# Moneyness Ratio = spot price / strike price
#
# Steps taken:
# 1. Define the STRIKE price (K);
# 2. Get current SPOT PRICE (S);
# 3. Compute the current MONEYNESS ratio (M);
# 4. Generate a sample of spot prices for which we want to get the respective IV;
# 5. Generate the corresponding sample strike prices, using the previously computed M;
# 6. Generate the sample implied volatilities for each sample strike price with the modeled cubic spline function;
# 7. Final result: (sample spot prices; sample implied volatilities);

# %% [markdown]
# **Function Definition**

# %%
from common import filter_dataframe_by_token_current_date_expiration_date_extrapolation

def get_iv_for_spot_price(
    current_spot_price: float, strike_price: float, sample_spot_price: float, iv_fit_function: callable
) -> float:
    """
    Calculate the implied volatility for a given spot price.

    Parameters:
    - current_spot_price (float): The current spot price of the asset.
    - strike_price (float): The strike price of the option.
    - sample_spot_price (float): The sample spot price for which to calculate implied volatility.
    - iv_fit_function (callable): A callable function that returns implied volatility for a given strike price.

    Returns:
    - float: The calculated sample implied volatility.
    """
    # Calculate the moneyness ratio based on current and strike prices
    moneyness_ratio = current_spot_price / strike_price

    # Adjust the strike price based on the sample spot price and moneyness ratio
    sample_strike_price = sample_spot_price / moneyness_ratio

    # Calculate the implied volatility for the sample strike price
    sample_iv = iv_fit_function(sample_strike_price)
    
    return sample_iv

def calculate_iv(
    current_spot_price: float, strike_price: float, sample_spot_price_values: list[float], iv_fit_function: callable
) -> list[float]:
    """
    Calculate the implied volatilities for a range of sample spot prices.

    Parameters:
    - df_filtered (pd.DataFrame): The filtered DataFrame.
    - current_spot_price (float): The current spot price.
    - strike_price (float): The strike price.
    - iv_fit_function (callable): The implied volatility fit function.

    Returns:
    - list: List of sample implied volatilities.
    """
    return [get_iv_for_spot_price(
        current_spot_price, strike_price, sample_spot_price, iv_fit_function
    ) for sample_spot_price in sample_spot_price_values]

def plot_iv(sample_spot_prices, sample_ivs, current_spot_price, strike_price, token, current_date, expiration_date):
    """
    Plot implied volatilities against sample spot prices.

    Parameters:
    - sample_spot_prices (list): List of sample spot prices.
    - sample_ivs (list): List of sample implied volatilities.
    - current_spot_price (float): The current spot price.
    - strike_price (float): The strike price.
    - token (str): The token.
    - current_date (str): The current date.
    - expiration_date (str): The expiration date.
    """
    plt.figure(figsize=(16, 9))
    plt.plot(sample_spot_prices, sample_ivs, color='blue', label='Predicted')
    plt.axvline(x=current_spot_price, color='black', linestyle='--', label='Current Spot Price')
    plt.axvline(x=strike_price, color='orange', linestyle='--', label='Strike Price')

    plt.title(f"Token: {token} | Current Date: {current_date} | Expiration Date: {expiration_date}", fontsize=14, fontweight='bold')
    plt.xlabel('Spot Price (in quote)')
    plt.ylabel('Implied Volatility')
    plt.legend()
    plt.show()


def implied_volatility_versus_spot_price(
    token:str, current_dates: np.ndarray, expiration_date: str, extrapolation_type: int
) -> None:
    # Main loop to process each date
    for current_date in current_dates:
        clear_output(wait=True)

        df_nodes_filtered = filter_dataframe_by_token_current_date_expiration_date_extrapolation(
            df_nodes, token, current_date, expiration_date, extrapolation_type
        )

        if df_nodes_filtered.size != 0:
            iv_fit_function = df_nodes_filtered['func_callable'].values[0]
            current_spot_price = df_nodes_filtered['S'].values[0]
            strike_price = 0.95 * current_spot_price
            sample_spot_price_values = np.linspace(0.5 * current_spot_price, 1.5 * current_spot_price, 50)

            sample_iv_values = calculate_iv(current_spot_price, strike_price, sample_spot_price_values, iv_fit_function)
            plot_iv(sample_spot_price_values, sample_iv_values, current_spot_price, strike_price, token, current_date, expiration_date)

            time.sleep(1)
            plt.close()

# %% [markdown]
# **Output**

# %%
token = 'axl'
expiration_date = '2023-12-29 08:00:00'
current_dates = df_nodes['current_date'].unique()
extrapolation_type = 0

implied_volatility_versus_spot_price(token, current_dates, expiration_date, extrapolation_type)

# %% [markdown]
# # 4. Term Structure of Volatility - Interpolation / Extrapolation

# %%
from IPython.display import clear_output, display
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
import math

from volatility_surface import VolatilitySurface
from common import format_dates

# %% [markdown]
# #### [VOLATILITY SURFACE - CLASS] Usecase

# %%
# Define Input Parameters
# -----------------------
token = 'eth'
current_date = '2023-11-18 00:00:00'
expiration_date = '2024-04-15 08:00:00'

interpolation_types = {
    'volatility_curve': 'cubic',
    'volatility_surface': 'linear'
}

extrapolation_types = {
    'volatility_curve': 'flat',
    'volatility_surface': 'square_root'
}

vs = VolatilitySurface(df_nodes, token, current_date, interpolation_types, extrapolation_types)
vs.load_expiration_date(expiration_date)

# Example
sample_strike = 2000
sample_iv = vs.iv_fit_function(sample_strike)

print(f"\nSample Strike: {sample_strike} | Sample Implied Volatility: {sample_iv}")

# %% [markdown]
# #### [INTERPOLATION / EXTRAPOLATION]

# %%
def plot_implied_volatility(ax, strike_prices, iv_values, expiration_date, labels, line_styles):
    """
    Plot implied volatility curves on the given matplotlib axis.

    Parameters:
    - ax (matplotlib.axes.Axes): Axes object for plotting.
    - strike_prices (array-like): Array of strike prices.
    - iv_values (list of array-like): Implied volatility values for each curve.
    - expiration_date (str): Expiration date for the options.
    - labels (list of str): Labels for each volatility curve.
    - line_styles (list of str): Line styles for each curve.
    """
    for i, iv_curve in enumerate(iv_values):
        ax.plot(strike_prices, iv_curve, label=labels[i], linestyle=line_styles[i])

    ax.set_xlabel('Strike Price')
    ax.set_ylabel('Implied Volatility')
    ax.legend()
    ax.set_title(f'Expiration Date: {expiration_date}')

def extrapolate_maturities(df_nodes: pd.DataFrame, tokens: list[str], interpolation_types: dict, extrapolation_type: dict, is_long_dated: bool):
    """
    Extrapolate implied volatility for given tokens and dates.

    Parameters:
    - df_nodes (pd.DataFrame): DataFrame containing option market data.
    - tokens (list of str): List of tokens to process.
    """
    for token in tokens:
        current_dates = df_nodes['current_date'].unique()
        current_dates = format_dates(np.array(current_dates))
        # current_dates = ['2023-11-25 00:00:00']  # Example date, in practice, use format_dates function

        for current_date in current_dates:
            clear_output(wait=True)
            current_spot = df_nodes.loc[(df_nodes['token'] == token) & (df_nodes['current_date'] == current_date), 'S'].values[0]
            sample_strike_values = np.linspace(0.5 * current_spot, 3 * current_spot, 100)
            expiration_dates = df_nodes.loc[(df_nodes['token'] == token) & (df_nodes['current_date'] == current_date), 'expiration_date'].values
            expiration_dates = format_dates(expiration_dates)  # Assuming format_dates function exists
            expiration_dates = expiration_dates[-3:] if is_long_dated else expiration_dates[:3]

            num_expiration_dates = len(expiration_dates) - 1
            num_rows = math.ceil(num_expiration_dates / 2)
            fig, axs = plt.subplots(num_rows, 2, figsize=(22, 6 * num_rows))
            axs = axs.flatten()

            i = 1  if is_long_dated else num_expiration_dates

            for ax, expiration_date in zip(axs, expiration_dates[1:] if is_long_dated else reversed(expiration_dates[:2])):

                # Instantiate VolatilitySurface and get implied volatility fit functions
                vs = VolatilitySurface(df_nodes, token, current_date, interpolation_types, extrapolation_types)
                vs.load_expiration_date(expiration_date)
                iv_fit_function_observed = vs.iv_fit_function
                
                # Predicted IV curves using different extrapolation methods
                filtered_expiration_dates = expiration_dates[:i] if is_long_dated else expiration_dates[i:]

                extrapolation_types['volatility_surface'] = 'flat'
                vs = VolatilitySurface(df_nodes.loc[df_nodes['expiration_date'].isin(filtered_expiration_dates)], token, current_date, interpolation_types, extrapolation_types)
                vs.load_expiration_date(expiration_date)
                iv_fit_function_predicted_flat = vs.iv_fit_function


                extrapolation_types['volatility_surface'] = 'square_root'
                vs = VolatilitySurface(df_nodes.loc[df_nodes['expiration_date'].isin(filtered_expiration_dates)], token, current_date, interpolation_types, extrapolation_types)
                vs.load_expiration_date(expiration_date)
                iv_fit_function_predicted_square_root = vs.iv_fit_function

                sample_iv_values = [
                    [iv_fit_function_observed(strike) for strike in sample_strike_values],
                    [iv_fit_function_predicted_flat(strike) for strike in sample_strike_values],
                    [iv_fit_function_predicted_square_root(strike) for strike in sample_strike_values]
                ]
                labels = ["Observed", "Extrapolated - Flat", "Extrapolated - Square Root"]
                line_styles = ['-', '--', '--']
            
                plot_implied_volatility(ax, sample_strike_values, sample_iv_values, expiration_date, labels, line_styles)

                i = i+1 if is_long_dated else i-1

            # Hide any unused subplots
            for i in range(num_expiration_dates, len(axs)):
                fig.delaxes(axs[i])

            plt.suptitle(f'Token: {token} | Current Date: {current_date} | Vol. Curve - Extrapolation Type:  {extrapolation_types["volatility_curve"]}', fontweight='bold')
            plt.subplots_adjust(top=0.9, hspace=0.3)
            plt.show()
            time.sleep(3)
            plt.close()

def interpolate_maturities(df_nodes: pd.DataFrame, tokens: list[str], interpolation_types: dict, extrapolation_type: dict):
    """
    Interpolate implied volatility for given tokens and dates.

    Parameters:
    - df_nodes (pd.DataFrame): DataFrame containing option market data.
    - tokens (list of str): List of tokens to process.
    """
    for token in tokens:
        unique_current_dates = df_nodes['current_date'].unique()
        current_dates = format_dates(np.array(unique_current_dates))
        # current_dates = ['2023-11-25 00:00:00']  # Example date, in practice, use format_dates function

        for current_date in current_dates:
            clear_output(wait=True)
            current_spot = df_nodes.loc[(df_nodes['token'] == token) & (df_nodes['current_date'] == current_date), 'S'].values[0]
            sample_strike_values = np.linspace(0.5 * current_spot, 3 * current_spot, 100)
            expiration_dates = df_nodes.loc[(df_nodes['token'] == token) & (df_nodes['current_date'] == current_date), 'expiration_date'].values
            expiration_dates = format_dates(expiration_dates)  # Assuming format_dates function exists
            expiration_dates = expiration_dates[1:-1]

            num_expiration_dates = len(expiration_dates)
            num_rows = math.ceil(num_expiration_dates / 2)
            fig, axs = plt.subplots(num_rows, 2, figsize=(22, 6 * num_rows))
            axs = axs.flatten()

            for ax, expiration_date in zip(axs, expiration_dates):

                # Instantiate VolatilitySurface and get implied volatility fit functions
                vs = VolatilitySurface(df_nodes, token, current_date, interpolation_types, extrapolation_types)
                vs.load_expiration_date(expiration_date)
                iv_fit_function_observed = vs.iv_fit_function
                
                # Predicted IV curves using different extrapolation methods
                interpolation_types['volatility_surface'] = 'linear'
                vs = VolatilitySurface(df_nodes.loc[df_nodes['expiration_date'] != expiration_date], token, current_date, interpolation_types, extrapolation_types)
                vs.load_expiration_date(expiration_date)
                iv_fit_function_predicted_linear = vs.iv_fit_function

                interpolation_types['volatility_surface'] = 'flat_forward'
                vs = VolatilitySurface(df_nodes.loc[df_nodes['expiration_date'] != expiration_date], token, current_date, interpolation_types, extrapolation_types)
                vs.load_expiration_date(expiration_date)
                iv_fit_function_predicted_flat_forward = vs.iv_fit_function

                sample_iv_values = [
                    [iv_fit_function_observed(strike) for strike in sample_strike_values],
                    [iv_fit_function_predicted_linear(strike) for strike in sample_strike_values],
                    [iv_fit_function_predicted_flat_forward(strike) for strike in sample_strike_values]
                ]
                labels = ["Observed", "Interpolated - Linear", "Interpolated - Flat Forward"]
                line_styles = ['-', '--', '--']
            
                plot_implied_volatility(ax, sample_strike_values, sample_iv_values, expiration_date, labels, line_styles)

            # Hide any unused subplots
            for i in range(num_expiration_dates, len(axs)):
                fig.delaxes(axs[i])

            plt.suptitle(f'Token: {token} | Current Date: {current_date} | Vol. Curve - Extrapolation Type: {extrapolation_types["volatility_curve"]}', fontweight='bold')
            plt.subplots_adjust(top=0.9, hspace=0.3)
            plt.show()
            time.sleep(3)
            plt.close()

# %% [markdown]
# #### TTE > TTE_max

# %%
# Constants
tokens = ['eth']

# Example call
extrapolate_maturities(df_nodes, tokens, interpolation_types, extrapolation_types, is_long_dated=True)

# %% [markdown]
# TTE < TTE_min

# %%
# Constants
tokens = ['eth']

# Example call
extrapolate_maturities(df_nodes, tokens, interpolation_types, extrapolation_types, is_long_dated=False)

# %% [markdown]
# #### TTE_min < TTE < TTE_max

# %%
# Constants
tokens = ['eth']

# Example call
interpolate_maturities(df_nodes, tokens, interpolation_types, extrapolation_types)
